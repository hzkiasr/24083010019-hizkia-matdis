# %%
import matplotlib.pyplot as plt

# Fungsi hitung Hn
def harmonic(n):
    return sum(1/k for k in range(1, n+1))

# %%
def harmonic(n):
    return sum(1/k for k in range(1, n+1))

for n in range(1, 11):  # cek n sampai 10
    Hn = harmonic(n)
    deviation = 2 - Hn
    check = Hn < 2
    print(f"n={n}, Hn={Hn:.4f}, Simpangan={deviation:.4f}, Status={check}")
# Out:
# n=1, Hn=1.0000, Simpangan=1.0000, Status=True
# n=2, Hn=1.5000, Simpangan=0.5000, Status=True
# n=3, Hn=1.8333, Simpangan=0.1667, Status=True
# n=4, Hn=2.0833, Simpangan=-0.0833, Status=False
# n=5, Hn=2.2833, Simpangan=-0.2833, Status=False
# n=6, Hn=2.4500, Simpangan=-0.4500, Status=False
# n=7, Hn=2.5929, Simpangan=-0.5929, Status=False
# n=8, Hn=2.7179, Simpangan=-0.7179, Status=False
# n=9, Hn=2.8290, Simpangan=-0.8290, Status=False
# n=10, Hn=2.9290, Simpangan=-0.9290, Status=False

# %% [markdown]
# n=1→H
# 1
#
# =1<2   True
#
#
# n=2→H
# 2
# =1.5<2  True
#
#
# n=3→H
# 3
# =1.833<2    True
#
# n=4→H
# 4
# =2.083>2 False
#
# Mulai  n=4, nilai
# 𝐻𝑛
# melewati angka 2, sehingga pernyataan tidak berlaku lagi.

# %%
# Plot grafik Hn dengan status True/False
plt.figure(figsize=(10,5))
plt.plot(n_values, H, marker='o', linestyle='-', label='Hn')
plt.axhline(2, color='r', linestyle='--', label='Batas 2')

# Tambahkan label True/False di tiap titik
for n, Hn, st in zip(n_values, H, status):
    label = "True" if st else "False"
    color = "green" if st else "red"
    plt.text(n, Hn+0.05, label, ha='center', color=color, fontsize=9, fontweight='bold')

plt.title("Grafik Hn dengan Status True/False")
plt.xlabel("n")
plt.ylabel("Hn")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# grafik Hn memperlihatkan pertumbuhan deret harmonik yang makin naik.  garis merah putus-putus adalah batas 2 terlihat bahwa n= 4 grafik Hn sudah melampaui batas

# %% [markdown]
# 𝐻
# 𝑛
# <
# 2
#
# tidak selalu benar hanya berlaku untuk
# 𝑛
# =
# 1
# ,
# 2
# ,
# 3
#
#
# mulai
# n=4 deret harmonik sudah melampaui 2, sehingga statusnya False.
#
# Simpangan di
# n=2 adalah 0.5, artinya jarak ke 2 masih lumayan besar, tapi semakin besar
# 𝑛, simpangan makin kecil lalu jadi negatif.
